# %%
# !pip show pandas
# Out:
# Name: pandas
# Version: 1.1.3
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: https://pandas.pydata.org
# Author: None
# Author-email: None
# License: BSD
# Location: /Users/luciapetersen/opt/anaconda3/lib/python3.8/site-packages
# Requires: python-dateutil, numpy, pytz
# Required-by: statsmodels, seaborn, pyreadstat

# %%
import pandas as pd
location='https://github.com/luciampetersen/PUBPOL542/blob/main/'
fileXLSX=location+'SeattleIncomeByZipCode.xlsx?raw=true'
dataExcel=pd.read_excel(fileXLSX)

# %%
dataExcel
# Out:
#     ZIPCODE  Number of returns  Adjusted gross income (AGI)     Avg AGI  \
# 0     98101               7890                      1074214  136.148796
# 1     98102              15880                      1505673   94.815680
# 2     98103              28150                      2404789   85.427673
# 3     98104               6580                       649157   98.656079
# 4     98105              15400                      1671227  108.521234
# 5     98106              12500                       625969   50.077520
# 6     98107              14480                      1121112   77.424862
# 7     98108              11780                       589150   50.012733
# 8     98109              15300                      1665311  108.843856
# 9     98110              11310                      1497096  132.369231
# 10    98112              12130                      2457229  202.574526
# 11    98115              25370                      2555944  100.746709
# ...

# %%
dataExcel=dataExcel.copy() # recreating DFTest
some=['ZIPCODE']

# %%
dict(zip(dataExcel.columns[1::], some))
# Out:
# {'Number of returns': 'ZIPCODE'}

# %%
DF=dataExcel

# %%
DFTest=DF.copy()

# %%
del DF['Adjusted gross income (AGI)']

# %%
del DF['Number of returns with total income']

# %%
del DF['Total income amount']

# %%
del DF['Avg total income']

# %%
del DF['Number of returns with taxable income']

# %%
del DF ['Taxable income amount']

# %%
del DF ['Avg taxable income']

# %%
DF
# Out:
#     ZIPCODE  Number of returns     Avg AGI
# 0     98101               7890  136.148796
# 1     98102              15880   94.815680
# 2     98103              28150   85.427673
# 3     98104               6580   98.656079
# 4     98105              15400  108.521234
# 5     98106              12500   50.077520
# 6     98107              14480   77.424862
# 7     98108              11780   50.012733
# 8     98109              15300  108.843856
# 9     98110              11310  132.369231
# 10    98112              12130  202.574526
# 11    98115              25370  100.746709
# 12    98116              13660   98.377599
# 13    98117              17560   93.953588
# 14    98118              22620   56.957781
# 15    98119              12450  111.552450
# 16    98121               8760  128.087100
# 17    98122              19510   77.256996
# 18    98125              20000   64.398200
# 19    98126              10950   70.937534
# 20    98133              24090   55.067206
# ...

# %%
DF.columns=['zipcode','number_of_returns','avg_adjusted_gross_income']

# %%
DF
# Out:
#     zipcode  number_of_returns  avg_adjusted_gross_income
# 0     98101               7890                 136.148796
# 1     98102              15880                  94.815680
# 2     98103              28150                  85.427673
# 3     98104               6580                  98.656079
# 4     98105              15400                 108.521234
# 5     98106              12500                  50.077520
# 6     98107              14480                  77.424862
# 7     98108              11780                  50.012733
# 8     98109              15300                 108.843856
# 9     98110              11310                 132.369231
# 10    98112              12130                 202.574526
# 11    98115              25370                 100.746709
# 12    98116              13660                  98.377599
# 13    98117              17560                  93.953588
# 14    98118              22620                  56.957781
# ...

# %%
DF.columns=['zipcode','number_of_returns','avg_AGI']

# %%
DF
# Out:
#     zipcode  number_of_returns     avg_AGI
# 0     98101               7890  136.148796
# 1     98102              15880   94.815680
# 2     98103              28150   85.427673
# 3     98104               6580   98.656079
# 4     98105              15400  108.521234
# 5     98106              12500   50.077520
# 6     98107              14480   77.424862
# 7     98108              11780   50.012733
# 8     98109              15300  108.843856
# 9     98110              11310  132.369231
# 10    98112              12130  202.574526
# 11    98115              25370  100.746709
# 12    98116              13660   98.377599
# 13    98117              17560   93.953588
# 14    98118              22620   56.957781
# 15    98119              12450  111.552450
# 16    98121               8760  128.087100
# 17    98122              19510   77.256996
# 18    98125              20000   64.398200
# 19    98126              10950   70.937534
# 20    98133              24090   55.067206
# ...

# %%
DF.to_excel(r'Desktop\CleanedSeattleIncomeByZip.xlsx', index = False)

# %%
DF.to_excel(r'/Users/luciapetersen/Desktop/CleanedSeattleIncomeByZip2013.xlsx', sheet_name='Sheet1', index = False)
